# %%
from TABprocessor import *

# %%
def song_greek(song):
    '''
    对多个小节进行希腊字母化并组合成句
    '''
    
    def tokenizer_preprocess(measurepitch):
        '''
        由于huggingface的分词会把类似4B4C这种带数字的分开，因此把数字和升降号换成字母
        '''
        xila = ['t', 'u', 'v', 'w', 'x', 'y', 'z', 'j', 'k'] 
        sentence = ''
        for cunum, cu in enumerate(measurepitch):
            if 'SUS' in cu or 'R' in cu:
                cu = cu.replace(' ', '')
                sentence += cu
                sentence += ' '
            else:
                notes = cu.split()
                for notenum, note in enumerate(notes):
                    notes[notenum] = xila[int(note[0])] + note[1:]
                    if len(note) > 2:
                        if note[-1] == '#':
                            notes[notenum] = notes[notenum][0:2] + 'j' 
                        elif note[-1] == '-':
                            notes[notenum] = notes[notenum][0:2] + 'k' 

                for note in notes:
                    sentence += note
                sentence += ' '
        return sentence[0:-1]
            
    def tokenizer_deprocess(sentence):
        '''
        希腊字母的逆变换
        '''
        measure = []
        xila = ['t', 'u', 'v', 'w', 'x', 'y', 'z', 'j', 'k']
        octave = [' 0', ' 1', ' 2', ' 3', ' 4', ' 5', ' 6', '#', '-']
        cus = sentence.split()
        for cu in cus:
            for i in range(len(xila)):
                cu = cu.replace(xila[i], octave[i])
            cu = cu[1:]
            measure.append(cu)
        return measure
    song_sentence = ''
    for measure in song:
        song_sentence += tokenizer_preprocess(measure)
        song_sentence += ', '

    song_sentence = song_sentence[0:-2]
    return song_sentence

sub_dataset = readTAB('C:\\Users\\28056\\Desktop\\研究生\\AnimeTAB\\AnimeTAB\\clips\\')
# Out:
# #####0. [Air]てんとう虫(瓢虫)_14^21C.xml
# #####1. [Air]てんとう虫(瓢虫)_2^5I.xml
# #####2. [Air]てんとう虫(瓢虫)_42^49B.xml
# #####3. [Air]てんとう虫(瓢虫)_6^13A.xml
# #####4. [Air]回想录_9^20B.xml
# #####5. [Air]夢語り_1^8A.xml
# #####6. [Air]夢語り_9^16B.xml
# #####7. [Air]银色_16^27B.xml
# #####8. [Air]鸟之诗_10^27B.xml
# #####9. [Air]鸟之诗_1^9I.xml
# #####10. [Air]鸟之诗_28^43A.xml
# #####11. [Air]鸟之诗_44^58C.xml
# #####12. [Angel Beats!]Brave Song_16^25C.xml
# #####13. [Angel Beats!]Brave Song_1^15A.xml
# #####14. [Angel Beats!]Brave Song_26^49B.xml
# #####15. [Angel Beats!]一番の宝物_1^8 I.xml
# #####16. [Angel Beats!]一番の宝物_9^24 A.xml
# #####17. [Beck]Face_13^23A.xml
# #####18. [Beck]Face_25^33B.xml
# #####19. [CLANNAD]メグメル(幻想)_1^15I.xml
# #####20. [CLANNAD]メグメル(幻想)_23^30A.xml
# #####21. [CLANNAD]メグメル(幻想)_31^49B.xml
# #####22. [CLANNAD]东风_10^26A.xml
# #####23. [CLANNAD]东风_1^9I.xml
# #####24. [CLANNAD]团子大家族_25^32C.xml
# #####25. [CLANNAD]团子大家族_33^48B.xml
# #####26. [CLANNAD]团子大家族_9^24A.xml
# #####27. [CLANNAD]欢乐岛_1^15I.xml
# #####28. [CLANNAD]欢乐岛_24^34A.xml
# #####29. [CLANNAD]欢乐岛_35^42C.xml
# #####30. [CLANNAD]汐_15^22 B.xml
# #####31. [CLANNAD]汐_2^14 A.xml
# #####32. [CLANNAD]白诘草_1^12A.xml
# #####33. [CLANNAD]空に光る_6^18B.xml
# #####34. [EVA]Fly me to the moon_17^24B.xml
# #####35. [EVA]Fly me to the moon_1^8I.xml
# #####36. [EVA]Fly me to the moon_9^16A.xml
# #####37. [EVA]Komm,susser tod_25^32C.xml
# #####38. [EVA]Komm,susser tod_9^24A.xml
# #####39. [EVA]残酷的天使纲领_10^17A.xml
# #####40. [EVA]残酷的天使纲领_18^33C.xml
# #####41. [EVA]残酷的天使纲领_1^9I.xml
# #####42. [EVA]残酷的天使纲领_34^45B.xml
# #####43. [Fate Stay Night]あなたがいた森_17^25A.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
# #####44. [Fate Stay Night]あなたがいた森_1^16A.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
#     ! In measure 9, sum of timesig should be 3.0, but6.0
#     ! In measure 10, sum of timesig should be 3.0, but6.0
#     ! In measure 11, sum of timesig should be 3.0, but6.0
#     ! In measure 12, sum of timesig should be 3.0, but6.0
#     ! In measure 13, sum of timesig should be 3.0, but6.0
#     ! In measure 14, sum of timesig should be 3.0, but6.0
#     ! In measure 15, sum of timesig should be 3.0, but6.0
# #####45. [Fate Stay Night]あなたがいた森_26^42B.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
#     ! In measure 9, sum of timesig should be 3.0, but6.0
#     ! In measure 10, sum of timesig should be 3.0, but6.0
#     ! In measure 11, sum of timesig should be 3.0, but6.0
#     ! In measure 12, sum of timesig should be 3.0, but6.0
#     ! In measure 13, sum of timesig should be 3.0, but6.0
#     ! In measure 14, sum of timesig should be 3.0, but6.0
#     ! In measure 15, sum of timesig should be 3.0, but6.0
#     ! In measure 16, sum of timesig should be 3.0, but6.0
# #####46. [Fate Stay Night]光_13^20C.xml
# #####47. [Fate Stay Night]光_1^4I.xml
# #####48. [Fate Stay Night]光_21^29B.xml
# #####49. [Fate Stay Night]光_5^12A.xml
# #####50. [Fate Stay Night]命运の夜_1^8 I.xml
# #####51. [Fate Stay Night]孤独的巡礼_13^20B.xml
# #####52. [Fate Stay Night]孤独的巡礼_1^4I.xml
# #####53. [Fate Stay Night]孤独的巡礼_5^12A.xml
# #####54. [Fate Zero]空は高く風は歌う_1^16 A.xml
# #####55. [Kanon]Last Regrets_17^32A.xml
# #####56. [Kanon]Last Regrets_33^54B.xml
# #####57. [Kanon]夢の跡_14^17C.xml
# #####58. [Kanon]夢の跡_18^30B.xml
# #####59. [Kanon]夢の跡_1^13A.xml
# #####60. [KOKIA]ありがとう(谢谢)_1^5I.xml
# #####61. [KOKIA]ありがとう(谢谢)_22^32B.xml
# #####62. [KOKIA]ありがとう(谢谢)_27^32B.xml
# #####63. [KOKIA]ありがとう(谢谢)_6^21A.xml
# #####64. [Little Busters!]遥か彼方_1^8A.xml
# #####65. [Little busters]Song for friends_17^20C.xml
#     ! In measure 0, sum of timesig should be 3.5, but7.0
#     ! In measure 1, sum of timesig should be 3.5, but7.0
#     ! In measure 2, sum of timesig should be 3.5, but7.0
#     ! In measure 3, sum of timesig should be 3.5, but7.0
# #####66. [Little busters]Song for friends_1^16A.xml
#     ! In measure 0, sum of timesig should be 3.5, but7.0
#     ! In measure 1, sum of timesig should be 3.5, but7.0
#     ! In measure 2, sum of timesig should be 3.5, but7.0
#     ! In measure 3, sum of timesig should be 3.5, but7.0
#     ! In measure 4, sum of timesig should be 3.5, but7.0
#     ! In measure 5, sum of timesig should be 3.5, but7.0
#     ! In measure 6, sum of timesig should be 3.5, but7.0
#     ! In measure 7, sum of timesig should be 3.5, but7.0
#     ! In measure 8, sum of timesig should be 3.5, but7.0
#     ! In measure 9, sum of timesig should be 3.5, but7.0
#     ! In measure 10, sum of timesig should be 3.5, but7.0
#     ! In measure 11, sum of timesig should be 3.5, but7.0
#     ! In measure 12, sum of timesig should be 3.5, but7.0
#     ! In measure 13, sum of timesig should be 3.5, but7.0
# #####172. [口袋妖怪]四天王_3^10A.xml
# #####173. [君が望む永遠]Rumbling hearts_29^44B.xml
# #####174. [君が望む永遠]Rumbling hearts_5^28A.xml
# #####175. [吸血鬼骑士]ふたつの鼓动と赤い罪_19^33A.xml
# #####176. [吸血鬼骑士]ふたつの鼓动と赤い罪_1^18I.xml
# #####177. [吸血鬼骑士]ふたつの鼓动と赤い罪_34^43C.xml
# #####178. [吸血鬼骑士]ふたつの鼓动と赤い罪_44^59B.xml
# #####179. [咲]咲OP_16^20C.xml
# #####180. [咲]咲OP_1^7I.xml
# #####181. [咲]咲OP_33^47B.xml
# #####182. [咲]咲OP_8^15A.xml
# #####183. [哆啦A梦]ひまわりの约束_19^26A.xml
# #####184. [哆啦A梦]ひまわりの约束_1^8I.xml
# #####185. [哈尔的移动城堡]世界的约定_16^23A.xml
# #####186. [哈尔的移动城堡]世界的约定_1^15I.xml
# #####187. [哈尔的移动城堡]世界的约定_24^31B.xml
# #####188. [哈尔的移动城堡]世界的约定_32^39C.xml
# #####189. [哈尔的移动城堡]人生的旋转木马_1^6I.xml
# #####190. [哈尔的移动城堡]人生的旋转木马_29^44B.xml
# #####191. [哈尔的移动城堡]人生的旋转木马_45^62C.xml
# #####192. [哈尔的移动城堡]人生的旋转木马_7^28A.xml
# #####193. [哈尔的移动城堡]苏菲的城堡_11^19B.xml
# #####194. [喜羊羊与灰太狼]喜羊羊与灰太狼主题曲_10^41A.xml
# #####195. [喜羊羊与灰太狼]喜羊羊与灰太狼主题曲_1^8I.xml
# #####196. [喜羊羊与灰太狼]喜羊羊与灰太狼主题曲_42^60B.xml
# #####197. [圣斗士]原谅我_15^28B.xml
# #####198. [圣斗士]原谅我_1^14A.xml
# #####199. [圣斗士]天马座的幻想_1^8I.xml
# #####200. [圣斗士]天马座的幻想_9^24A.xml
# #####201. [圣斗士]真红的少年_17^24B.xml
# #####202. [圣斗士]真红的少年_1^16A.xml
# #####203. [圣斗士]真红的少年_25^37A.xml
# #####204. [地狱少女]蓝染_19^34A.xml
# #####205. [地狱少女]蓝染_35^61B.xml
# #####206. [地狱少女]蓝染_63^78A.xml
# #####207. [地狱少女]逆蝶_1^8I.xml
#     ! In measure 0, sum of timesig should be 2.0, but4.0
#     ! In measure 1, sum of timesig should be 2.0, but4.0
#     ! In measure 2, sum of timesig should be 2.0, but4.0
#     ! In measure 3, sum of timesig should be 2.0, but4.0
#     ! In measure 4, sum of timesig should be 2.0, but4.0
#     ! In measure 5, sum of timesig should be 2.0, but4.0
#     ! In measure 6, sum of timesig should be 2.0, but4.0
#     ! In measure 7, sum of timesig should be 2.0, but4.0
# #####208. [地狱少女]逆蝶_41^56B.xml
#     ! In measure 0, sum of timesig should be 2.0, but4.0
#     ! In measure 1, sum of timesig should be 2.0, but4.0
#     ! In measure 2, sum of timesig should be 2.0, but4.0
#     ! In measure 3, sum of timesig should be 2.0, but4.0
#     ! In measure 4, sum of timesig should be 2.0, but4.0
#     ! In measure 5, sum of timesig should be 2.0, but4.0
#     ! In measure 6, sum of timesig should be 2.0, but4.0
#     ! In measure 7, sum of timesig should be 2.0, but4.0
#     ! In measure 8, sum of timesig should be 2.0, but4.0
#     ! In measure 9, sum of timesig should be 2.0, but4.0
#     ! In measure 10, sum of timesig should be 2.0, but4.0
#     ! In measure 11, sum of timesig should be 2.0, but4.0
#     ! In measure 12, sum of timesig should be 2.0, but4.0
#     ! In measure 13, sum of timesig should be 2.0, but4.0
#     ! In measure 14, sum of timesig should be 2.0, but4.0
#     ! In measure 15, sum of timesig should be 2.0, but4.0
# #####209. [地狱少女]逆蝶_9^40A.xml
#     ! In measure 0, sum of timesig should be 2.0, but4.0
#     ! In measure 1, sum of timesig should be 2.0, but4.0
#     ! In measure 2, sum of timesig should be 2.0, but4.0
#     ! In measure 3, sum of timesig should be 2.0, but4.0
#     ! In measure 4, sum of timesig should be 2.0, but4.0
#     ! In measure 5, sum of timesig should be 2.0, but4.0
#     ! In measure 6, sum of timesig should be 2.0, but4.0
#     ! In measure 7, sum of timesig should be 2.0, but4.0
#     ! In measure 8, sum of timesig should be 2.0, but4.0
#     ! In measure 9, sum of timesig should be 2.0, but4.0
#     ! In measure 10, sum of timesig should be 2.0, but4.0
#     ! In measure 11, sum of timesig should be 2.0, but4.0
#     ! In measure 12, sum of timesig should be 2.0, but4.0
#     ! In measure 13, sum of timesig should be 2.0, but4.0
#     ! In measure 14, sum of timesig should be 2.0, but4.0
#     ! In measure 15, sum of timesig should be 2.0, but4.0
#     ! In measure 16, sum of timesig should be 2.0, but4.0
#     ! In measure 17, sum of timesig should be 2.0, but4.0
#     ! In measure 18, sum of timesig should be 2.0, but4.0
#     ! In measure 19, sum of timesig should be 2.0, but4.0
#     ! In measure 20, sum of timesig should be 2.0, but4.0
#     ! In measure 21, sum of timesig should be 2.0, but4.0
#     ! In measure 22, sum of timesig should be 2.0, but4.0
#     ! In measure 23, sum of timesig should be 2.0, but4.0
#     ! In measure 24, sum of timesig should be 2.0, but4.0
#     ! In measure 25, sum of timesig should be 2.0, but4.0
#     ! In measure 26, sum of timesig should be 2.0, but4.0
#     ! In measure 27, sum of timesig should be 2.0, but4.0
#     ! In measure 28, sum of timesig should be 2.0, but4.0
#     ! In measure 29, sum of timesig should be 2.0, but4.0
#     ! In measure 30, sum of timesig should be 2.0, but4.0
#     ! In measure 31, sum of timesig should be 2.0, but4.0
# #####210. [夏目友人帐]いとはかなし_1^8A.xml
# #####211. [夏目友人帐]いとはかなし_9^20B.xml
# #####212. [夏目友人帐]夏夕空_13^19C.xml
# #####213. [夏目友人帐]夏夕空_1^4I.xml
# #####214. [夏目友人帐]夏夕空_20^29B.xml
# #####215. [夏目友人帐]夏夕空_5^12A.xml
# #####216. [夏目友人帐]春を知らせるもの_18^25B.xml
# #####217. [夏目友人帐]春を知らせるもの_1^17A.xml
# #####218. [多啦A梦]多啦A梦_19^26B.xml
# #####219. [多啦A梦]多啦A梦_1^8I.xml
# #####220. [多啦A梦]多啦A梦_27^34C.xml
# #####221. [多啦A梦]多啦A梦_9^18A.xml
# #####222. [天空之城]拉普达_15^26A.xml
# #####223. [天空之城]拉普达_26^35C.xml
# #####224. [天空之城]拉普达_36^51B.xml
# #####225. [天空之城]月光的云海_14^28B.xml
# #####226. [天空之城]月光的云海_1^13A.xml
# #####227. [天降之物]帰るから_20^27B.xml
# #####228. [天降之物]帰るから_2^5I.xml
# #####229. [天降之物]帰るから_6^13A.xml
# #####230. [女生爱女生]坚定少女的心_1^8A.xml
# #####231. [好想告诉你]Pure white story_5^20A.xml
# #####232. [妖精的尾巴]キミがくれたもの(你给我的东西)_10^14C.xml
# #####233. [妖精的尾巴]キミがくれたもの(你给我的东西)_15^22B.xml
# #####234. [妖精的尾巴]キミがくれたもの(你给我的东西)_2^9A.xml
# #####235. [妖精的旋律]Lilium_1^20A.xml
# #####236. [学园孤岛]想要成为好朋友_14^21B.xml
# #####237. [学园孤岛]想要成为好朋友_22^29A.xml
# #####238. [学园孤岛]想要成为好朋友_6^13B.xml
# #####239. [寂静岭]promise reprise_1^12A.xml
# #####240. [寂静岭]Promise_1^8I.xml
# #####241. [寂静岭]Promise_29^36B.xml
# #####242. [寂静岭]Promise_9^28A.xml
# #####355. [水星领航员]Rainbow_18^26B.xml
# #####356. [水星领航员]Rainbow_1^4I.xml
# #####357. [水星领航员]Rainbow_5^12A.xml
# #####358. [水果篮子]For fruits basket_21^34B.xml
# #####359. [水果篮子]For fruits basket_35^43C.xml
# #####360. [水果篮子]For fruits basket_5^20A.xml
# #####361. [泡泡堂]小区_11^14B.xml
# #####362. [泡泡堂]小区_3^10A.xml
# #####363. [泡泡堂]海盗船_1^8A.xml
# #####364. [浪客剑心]そばかす_1^8I.xml
# #####365. [浪客剑心]そばかす_27^39C.xml
# #####366. [浪客剑心]そばかす_40^58B.xml
# #####367. [浪客剑心]そばかす_9^26A.xml
# #####368. [浪漫满屋]命运_12^27A.xml
# #####369. [浪漫满屋]命运_28^43B.xml
# #####370. [浪漫满屋]命运_2^9I.xml
# #####371. [海贼王]宾克斯的美酒_2^10B.xml
# #####372. [漫画家与助手]Spica_1^6A.xml
# #####373. [漫画家与助手]Spica_7^14B.xml
# #####374. [灌篮高手]直到世界的尽头_18^36B.xml
# #####375. [灌篮高手]直到世界的尽头_2^17A.xml
# #####376. [火影]Alone_13^20C.xml
# #####377. [火影]Alone_1^4I.xml
# #####378. [火影]Alone_23^32B.xml
# #####379. [火影]Alone_5^12A.xml
# #####380. [火影]Sadness and sorrow_1^8I.xml
# #####381. [火影]Sadness and sorrow_20^33B.xml
# #####382. [火影]Sadness and sorrow_9^19A.xml
# #####383. [火影]三代火影的葬礼_17^29A.xml
# #####384. [火影]三代火影的葬礼_30^37B.xml
# #####385. [灼眼的夏娜]绯色之空_11^24B.xml
# #####386. [灼眼的夏娜]绯色之空_1^10A.xml
# #####387. [狼与香辛料]旅の途中_1^8I.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
# #####388. [狼与香辛料]旅の途中_25^33C.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
# #####389. [狼与香辛料]旅の途中_35^50B.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
#     ! In measure 9, sum of timesig should be 3.0, but6.0
#     ! In measure 10, sum of timesig should be 3.0, but6.0
#     ! In measure 11, sum of timesig should be 3.0, but6.0
#     ! In measure 12, sum of timesig should be 3.0, but6.0
#     ! In measure 13, sum of timesig should be 3.0, but6.0
#     ! In measure 14, sum of timesig should be 3.0, but6.0
#     ! In measure 15, sum of timesig should be 3.0, but6.0
# #####390. [狼与香辛料]旅の途中_51^63C.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
#     ! In measure 9, sum of timesig should be 3.0, but6.0
#     ! In measure 10, sum of timesig should be 3.0, but6.0
#     ! In measure 11, sum of timesig should be 3.0, but6.0
#     ! In measure 12, sum of timesig should be 3.0, but6.0
# #####391. [狼与香辛料]旅の途中_9^24A.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
#     ! In measure 9, sum of timesig should be 3.0, but6.0
#     ! In measure 10, sum of timesig should be 3.0, but6.0
#     ! In measure 11, sum of timesig should be 3.0, but6.0
#     ! In measure 12, sum of timesig should be 3.0, but6.0
#     ! In measure 13, sum of timesig should be 3.0, but6.0
#     ! In measure 14, sum of timesig should be 3.0, but6.0
#     ! In measure 15, sum of timesig should be 3.0, but6.0
# #####392. [猎人]魂魄之挽歌C调_10^17A.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
# #####393. [猎人]魂魄之挽歌C调_18^34B.xml
#     ! In measure 0, sum of timesig should be 3.0, but6.0
#     ! In measure 1, sum of timesig should be 3.0, but6.0
#     ! In measure 2, sum of timesig should be 3.0, but6.0
#     ! In measure 3, sum of timesig should be 3.0, but6.0
#     ! In measure 4, sum of timesig should be 3.0, but6.0
#     ! In measure 5, sum of timesig should be 3.0, but6.0
#     ! In measure 6, sum of timesig should be 3.0, but6.0
#     ! In measure 7, sum of timesig should be 3.0, but6.0
#     ! In measure 8, sum of timesig should be 3.0, but6.0
#     ! In measure 9, sum of timesig should be 3.0, but6.0
#     ! In measure 10, sum of timesig should be 3.0, but6.0
#     ! In measure 11, sum of timesig should be 3.0, but6.0
#     ! In measure 12, sum of timesig should be 3.0, but6.0
#     ! In measure 13, sum of timesig should be 3.0, but6.0
#     ! In measure 14, sum of timesig should be 3.0, but6.0
#     ! In measure 15, sum of timesig should be 3.0, but6.0
#     ! In measure 16, sum of timesig should be 3.0, but6.0
# #####394. [白色相簿2]POWDER SNOW_19^27 C.xml
# #####395. [白色相簿2]POWDER SNOW_28^37 B.xml
# #####510. [高达]晓之车_5^12A.xml
# #####511. [鬼泣]Tender Surrender_1^17A.xml
# #####512. [魔兽世界]alliance tavern_17^32B.xml
# #####513. [魔兽世界]alliance tavern_1^8A.xml
# #####514. [魔兽世界]alliance tavern_9^16A.xml
# #####515. [魔兽世界]slaughtered lamb_41^56B.xml
# #####516. [魔兽世界]slaughtered lamb_9^24A.xml
# #####517. [魔兽世界]temple of the moon_17^32B.xml
# #####518. [魔兽世界]temple of the moon_1^16A.xml
# #####519. [魔兽世界]亡灵序曲_15^22B.xml
# #####520. [魔兽世界]亡灵序曲_1^14A.xml
# #####521. [魔力女管家]归途_21^37C.xml
# #####522. [魔力女管家]归途_38^58B.xml
# #####523. [魔力女管家]归途_5^20A.xml
# #####524. [魔女宅急便]母亲的扫帚_12^19C.xml
# #####525. [魔女宅急便]母亲的扫帚_1^11A.xml
# #####526. [魔女宅急便]母亲的扫帚_20^29B.xml
# #####527. [魔女宅急便]能看见海的城市_1^8A.xml
# #####528. [魔女宅急便]能看见海的城市_9^16B.xml
# #####529. [魔女宅急便]风之丘_20^28B.xml
# #####530. [魔女宅急便]风之丘_29^37A.xml
# #####531. [魔女宅急便]风之丘_38^49B.xml
# #####532. [魔女宅急便]风之丘_4^19A.xml
# #####533. [魔法少女小圆]Connect_18^33A.xml
# #####534. [魔法少女小圆]Connect_1^17I.xml
# #####535. [魔法少女小圆]Connect_34^49C.xml
# #####536. [魔法少女小圆]Connect_50^65B.xml
# #####537. [魔法少女小圆]Untitled Soundtrack_17^35B.xml
# #####538. [魔法少女小圆]Untitled Soundtrack_2^16A.xml
# #####539. [黑猫]世界之歌_1^12A.xml
# #####540. [黑猫]世界之歌_25^37B.xml
# #####541. [黑猫警长]黑猫警长OP_14^23B.xml
# #####542. [黑猫警长]黑猫警长OP_2^13A.xml
# #####543. [龙猫]邻家的龙猫_11^30A.xml
# #####544. [龙猫]邻家的龙猫_31^48B.xml
# #####545. [龙猫]风之涌道_1^8A.xml
# #####546. [龙猫]风之涌道_9^16B.xml

# %%
#备份一份歌曲
import copy
sentences, root_sentences = [], []
copy_dataset = []
for song in sub_dataset:
    copy_dataset.append(copy.deepcopy(song))

# %%
all_keys = ['C', 'D', 'E', 'F', 'G', 'A', 'B', 'C#', 'D#', 'F#', 'G#', 'A#']
division = 16

# %%
for i, osong in enumerate(copy_dataset):
    if i not in [397, 400, 411, 413] and osong.info.beat == '4':
        for key in all_keys:
            
            
            song = copy.deepcopy(osong)
            newsong = Tablature(pitch=None, finger=None, time=None)
            newsong.pitch = song.key_shift(key)
            newsong.finger = song.finger
            newsong.time = song.time
            newsong.info = song.info
            vec_song = newsong.vectorization(division=division)
            try:
                assert len([i for i in vec_song.pitch if len(i) != division]) == 0
                sentence = song_greek(vec_song.pitch)
                sentences.append(sentence)
            
            except:
                print(i, copy_dataset[i].info.name)
                print([len(i) for i in vec_song.pitch if len(i) != division])
            
            
            root_song = newsong.root_and_melody()
            vec_root_song = root_song.vectorization(division=division)
            
            try:
                assert len([i for i in vec_root_song.pitch if len(i) != division]) == 0    
                root_sentence = song_greek(vec_root_song.pitch)
                root_sentences.append(root_sentence)
            except:
                '''print(i, copy_dataset[i].info.name)
                print([len(i) for i in vec_root_song.pitch if len(i) != division])'''
                0
        del(osong)
# Out:
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 0 てんとう虫(瓢虫)_14^21C
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 2 てんとう虫(瓢虫)_42^49B
# [15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 60 ありがとう(谢谢)_1^5I
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 98 暮色蒼然_2^9A
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 102 碎月_22^28B
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 103 碎月_4^20A
# [15, 15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 108 你的声音_9^16A
# [15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 117 那就是爱吧_5^15A
# [15, 15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 136 Risky Game_10^17A
# [15]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 171 四天王_11^22B
# [28]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 182 咲OP_8^15A
# [15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 199 天马座的幻想_1^8I
# [14, 15, 14, 15, 14, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 200 天马座的幻想_9^24A
# [15, 15, 15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 214 夏夕空_20^29B
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 234 キミがくれたもの(你给我的东西)_2^9A
# [15]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 244 叹息之森_1^14I
# [14, 15, 26, 26]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 255 最棒的单相思_9^24A
# [15, 15, 15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 281 Breezy_1^16A
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 289 Melodies of life_25^32C
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 308 素敌だね_1^12I
# [15]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 311 陆行鸟_3^20A
# [14, 14, 15, 14, 14, 14, 15, 14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 335 Graze the Roof_27^38C
# [14]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 355 Rainbow_18^26B
# [15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 357 Rainbow_5^12A
# [15, 15]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 378 Alone_23^32B
# [14]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 394 POWDER SNOW_19^27 C
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 395 POWDER SNOW_28^37 B
# [15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 396 POWDER SNOW_2^18 A
# [15, 15]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 399 予感_43^51C
# [22]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 404 End theme_10^25B
# [15, 14, 15, 15, 14, 13, 14, 13, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 405 End theme_1^9A
# [14, 15, 14, 15]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 427 不变的永远_34^43C
# [8, 9, 8, 13]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 436 Planetes_1^4I
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 439 Planetes_9^20C
# [15]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 441 月光传说_2^6I
# [15, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 452 It's only a fairy tale_47^56B
# [14, 14]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 457 ハナミズキ_1^4I
# [15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 459 菊次郎的夏天_7^21B
# [15, 15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 477 相遇天使_11^26A
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 478 相遇天使_1^10I
# [15]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 480 兄弟_11^14C
# [14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 481 兄弟_15^18B
# [14, 14, 14]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 483 兄弟_3^10A
# [14, 14, 14, 10, 11, 11, 12]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 499 鸟之人_14^20A
# [15]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 502 鸟之人_44^53B
# [22, 22]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 539 世界之歌_1^12A
# [15, 15, 15, 14, 15, 15, 15, 14, 15, 14, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]
# 540 世界之歌_25^37B
# [13, 14, 15, 14, 15, 15]

# %%
root_sentences[0]
# Out:
# 'wAvF SUS SUS SUS SUS SUS wG SUS wAvF SUS xC SUS wA wG SUS SUS, wGvE SUS wA SUS wDvE SUS wG SUS wEvE SUS SUS SUS wDvE SUS SUS SUS, wCvF SUS SUS SUS vAvF SUS wC SUS wDvF SUS SUS wG wEvF SUS SUS SUS, wEvE SUS SUS SUS wG SUS wA SUS wBvE SUS SUS SUS wG SUS wA SUS, xCvF SUS SUS SUS SUS SUS wA SUS wGvF SUS wA xC wA wG wA xC, xDvE SUS xC SUS xD SUS xG SUS xEvE SUS SUS SUS xD SUS xE SUS, xCvF SUS wA SUS wFwC SUS SUS SUS xDvE SUS wB SUS wG SUS SUS SUS, wDvA SUS SUS SUS wCjvE SUS SUS SUS wAvA SUS SUS SUS SUS SUS SUS SUS'

# %%
import tokenizers
import tensorflow as tf
from tensorflow import keras
from transformers import AutoTokenizer, TFGPT2LMHeadModel, AutoConfig
import matplotlib.pyplot as plt

from tokenizers import (
    decoders,
    models,
    normalizers,
    pre_tokenizers,
    processors,
    trainers,
    Tokenizer
)

# %%
music_tokenizer = Tokenizer(models.BPE())
music_tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel(add_prefix_space=False)
#music_tokenizer.pre_tokenizer.pre_tokenize_str(sentence1)

trainer = trainers.BpeTrainer(vocab=5000, special_tokens=["[PAD]", '<s>', '</s>', '[MSK]', '[CLS]', '[EOS]'])
'''
<s>:小节开始
</s>:小节结束
SUS:延音
'CLS':整首歌开始
'EOS'：整首歌结束
'''
music_tokenizer.train_from_iterator(root_sentences, trainer=trainer)
music_tokenizer.post_processor = processors.ByteLevel(trim_offsets=False)
music_tokenizer.save('C:\\Users\\28056\\Desktop\\研究生\\AnimeTAB\\AnimeTAB\\tokenizer_save\\music_tokenizer_8_5.json')

# %%
music_tokenizer.encode('<s> 5C 4C 3G SUS </s>', add_special_tokens=True).ids
# Out:
# [1, 24, 9, 24, 9, 24, 13, 27, 24, 2]

# %%
root_sentences[0]
total_num = 0
error_num = 0
for songnum, sentence in enumerate(sentences):
    for measurenum, measure in enumerate(sentence.split(', ')):
        total_num += 1
        if len(measure.split(' ')) != division:
            error_num += 1
            print('song {} measure {}:'.format(songnum, measurenum))
            print(measure)

# %%
print(total_num, error_num)
# Out:
# 58596 0

# %%
root_sentences[0]
# Out:
# 'wAvF SUS SUS SUS SUS SUS wG SUS wAvF SUS xC SUS wA wG SUS SUS, wGvE SUS wA SUS wDvE SUS wG SUS wEvE SUS SUS SUS wDvE SUS SUS SUS, wCvF SUS SUS SUS vAvF SUS wC SUS wDvF SUS SUS wG wEvF SUS SUS SUS, wEvE SUS SUS SUS wG SUS wA SUS wBvE SUS SUS SUS wG SUS wA SUS, xCvF SUS SUS SUS SUS SUS wA SUS wGvF SUS wA xC wA wG wA xC, xDvE SUS xC SUS xD SUS xG SUS xEvE SUS SUS SUS xD SUS xE SUS, xCvF SUS wA SUS wFwC SUS SUS SUS xDvE SUS wB SUS wG SUS SUS SUS, wDvA SUS SUS SUS wCjvE SUS SUS SUS wAvA SUS SUS SUS SUS SUS SUS SUS'

# %%
inputs, labels = [], []
for sentence in root_sentences:
    measures = sentence.split(', ')
    for measure in measures:
        new_sentence = ''
        new_sentence += '<s>'
        new_sentence += measure
        new_sentence += '</s>'

        inputs.append(music_tokenizer.encode(new_sentence).ids)
        

print(inputs[0])
# Out:
# [1, 773, 27, 27, 27, 27, 27, 55, 27, 204, 27, 45, 27, 51, 55, 27, 27, 2]

# %%
max_len = max([len(i) for i in inputs])
inputs = [np.array(i, dtype='int32') for i in inputs if len(i) <= max_len]
print(max_len)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3888/1158855900.py in <module>
# ----> 1 max_len = max([len(i) for i in inputs])
#       2 inputs = [np.array(i, dtype='int32') for i in inputs if len(i) <= max_len]
#       3 print(max_len)
#
# NameError: name 'inputs' is not defined

# %%
new_inputs, attention_masks = [], []
for input1 in inputs:
    new_inputs.append(np.hstack((input1, np.zeros((max_len - input1.shape[0]), dtype='int32'))))
    attention_masks.append(np.hstack((np.zeros(len(input1)), np.ones(max_len - len(input1)))))

# %%
print(new_inputs[0].shape)
print(attention_masks[0].shape)
# Out:
# (19,)
# (19,)

# %%
inputs = [i[:-1].reshape(1, -1) for i in new_inputs]
inputs = np.concatenate(inputs, axis=0)
labels = [i[1:].reshape(1, -1) for i in new_inputs]
labels = np.concatenate(labels, axis=0)
labels[labels == 0] = 0
attention_masks =  np.concatenate([i[:-1].reshape(1, -1) for i in attention_masks], axis=0)
print(inputs.shape)
print(labels.shape)
print(attention_masks.shape)
# Out:
# (58992, 18)
# (58992, 18)
# (58992, 18)

# %%
val_inputs, val_labels = inputs[:500], labels[:500]
inputs, labels = inputs[500:], labels[500:]


BUFFER_SIZE = 1000
BATCH_SIZE = 32
dataset = tf.data.Dataset.from_tensor_slices((inputs, labels))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_inputs, val_labels))
val_dataset = val_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
from transformers import GPT2Config, TFGPT2LMHeadModel
# creating the configurations from which the model can be made
config = GPT2Config(
    vocab_size=len(music_tokenizer.get_vocab()),
    n_layer=1,
    n_head=2,
    n_embed=256,
    bos_token_id=1,
    eos_token_id=2,
    pad_token_id=0,
    
    
    
)

# creating the model
model = TFGPT2LMHeadModel(config)

# defining our optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=4e-5, epsilon=1e-08, clipnorm=1.0)
# definining our loss function
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# defining our metric which we want to observe
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
# compiling the model
model.compile(optimizer=optimizer, loss=[loss, *[None] * model.config.n_layer], metrics=[metric])
num_epoch = 50
#model.summary()

# %%
history = model.fit(dataset, validation_data = val_dataset, batch_size=BATCH_SIZE, epochs=num_epoch)
# Out:
# Epoch 1/50
# 1828/1828 [==============================] - 33s 18ms/step - loss: 1.0032 - accuracy: 0.7567 - val_loss: 2.5711 - val_accuracy: 0.6139
# Epoch 2/50
# 1828/1828 [==============================] - 33s 18ms/step - loss: 0.9985 - accuracy: 0.7578 - val_loss: 2.5660 - val_accuracy: 0.6153
# Epoch 3/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9939 - accuracy: 0.7589 - val_loss: 2.5827 - val_accuracy: 0.6109
# Epoch 4/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9900 - accuracy: 0.7598 - val_loss: 2.5928 - val_accuracy: 0.6151
# Epoch 5/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9859 - accuracy: 0.7603 - val_loss: 2.5949 - val_accuracy: 0.6153
# Epoch 6/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9809 - accuracy: 0.7615 - val_loss: 2.5949 - val_accuracy: 0.6154
# Epoch 7/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9773 - accuracy: 0.7626 - val_loss: 2.6289 - val_accuracy: 0.6120
# Epoch 8/50
# 1828/1828 [==============================] - 33s 18ms/step - loss: 0.9745 - accuracy: 0.7632 - val_loss: 2.6340 - val_accuracy: 0.6141
# Epoch 9/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9699 - accuracy: 0.7641 - val_loss: 2.6192 - val_accuracy: 0.6122
# Epoch 10/50
# 1828/1828 [==============================] - 34s 19ms/step - loss: 0.9656 - accuracy: 0.7649 - val_loss: 2.6378 - val_accuracy: 0.6112
# Epoch 11/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.9624 - accuracy: 0.7660 - val_loss: 2.6532 - val_accuracy: 0.6173
# Epoch 12/50
# 1828/1828 [==============================] - 34s 19ms/step - loss: 0.9597 - accuracy: 0.7661 - val_loss: 2.6592 - val_accuracy: 0.6149
# Epoch 13/50
# 1828/1828 [==============================] - 34s 19ms/step - loss: 0.9563 - accuracy: 0.7674 - val_loss: 2.6485 - val_accuracy: 0.6119
# Epoch 14/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.
50
# 1828/1828 [==============================] - 36s 20ms/step - loss: 0.8932 - accuracy: 0.7811 - val_loss: 2.8442 - val_accuracy: 0.6110
# Epoch 44/50
# 1828/1828 [==============================] - 36s 20ms/step - loss: 0.8929 - accuracy: 0.7813 - val_loss: 2.8391 - val_accuracy: 0.6138
# Epoch 45/50
# 1828/1828 [==============================] - 36s 20ms/step - loss: 0.8891 - accuracy: 0.7818 - val_loss: 2.8598 - val_accuracy: 0.6089
# Epoch 46/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.8880 - accuracy: 0.7821 - val_loss: 2.8799 - val_accuracy: 0.6116
# Epoch 47/50
# 1828/1828 [==============================] - 34s 19ms/step - loss: 0.8865 - accuracy: 0.7829 - val_loss: 2.9010 - val_accuracy: 0.6128
# Epoch 48/50
# 1828/1828 [==============================] - 36s 20ms/step - loss: 0.8854 - accuracy: 0.7831 - val_loss: 2.8721 - val_accuracy: 0.6120
# Epoch 49/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.8845 - accuracy: 0.7834 - val_loss: 2.8687 - val_accuracy: 0.6118
# Epoch 50/50
# 1828/1828 [==============================] - 35s 19ms/step - loss: 0.8829 - accuracy: 0.7836 - val_loss: 2.8689 - val_accuracy: 0.6151

# %%
from transformers import WEIGHTS_NAME, CONFIG_NAME
import os
output_dir = './model_8_6_generation/'
# creating directory if it is not present
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
model_to_save = model.module if hasattr(model, 'module') else model
output_model_file = os.path.join(output_dir, WEIGHTS_NAME)
output_config_file = os.path.join(output_dir, CONFIG_NAME)
# save model and model configs

model.save_pretrained(output_dir)
model_to_save.config.to_json_file(output_config_file)

# %%
# save tokenizer
music_tokenizer.save('music_tokenizer_8_6.json')

# %%
def show_history(history, aspect):
    plt.figure()
    plt.plot(history.history[aspect], label=aspect)
    plt.legend()
show_history(history, 'loss')
show_history(history, 'accuracy')

# %%
model()
# Out:
# (<tf.Tensor: shape=(32, 18), dtype=int32, numpy=
# array([[   1,  228,   78,   27,   27,   27,   27,   27,   27,   27,   27,
#           27,   27,   27,   27,   27,   27,   27],
#        [   1, 1047,   27,   27,   27,   43,   27,  105,  216,   27,   27,
#           27,   27,   44,   27,   40,   27,    2],
#        [   1,   97,   27,   89,   27,   27,   27,   65,   27,   27,   27,
#           27,   27,   45,   41,   41,   36,    2],
#        [   1, 1181,   27,   44,   27,   45,   27,   44,   27,   40,   27,
#           38,   27,   47,   27,   53,   27,    2],
#        [   1,  650,   27,   84,   27,   70,   27,   46,   46,   27,   27,
#          196,   27,   46,   27,   48,   27,    2],
#        [   1, 1267,   27,   51,   27,  212,   27,  125,   27,   38,   27,
#           41,   27,   51,   27,   50,   27,    2],
#        [   1,  964,   27,   75,   27,   59,   58,   54,   27,   27,   27,
#           59,   27,   75,   27,   27,   27,    2],
#        [   1,  776,   27,   38,   27,   47,   27,   56,   27,   27,   27,
#           81,   27,   91,   27,  101,   27,    2],
#        [   1,  141,   96,   27,   27,   27,   27,   27,   36,   27,   27,
#           27,   37,   27,   42,   27,   56,   27],
#        [   1,   97,   27,   89,   27,   27,   27,   36,   27,   27,   27,
#           55,   27,   45,   27,   36,   27,    2],
#        [   1,   92,  102,   27,   98,   27,   27,   27,   55,   27,   51,
#           27,   41,   27,  182,   27,   41,   27],
#        [   1, 1441,   27,   27,   27,   49,   27,  267,  461,   27,   27,
#           27,   27,   65,   27,   58,   27,    2],
#        [   1, 1096,   27,   27,   27,  191,   27,  212,   27,  125,   27,
