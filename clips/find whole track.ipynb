# %%
import os
import shutil

# %%
XML_files = os.listdir(os.getcwd())
XML_files = [file for file in XML_files if '.xml' in file]

# %%
for i in range(len(XML_files)):
    XML_files[i] = XML_files[i].split('_')[0]
    
print(XML_files)
# Out:
# ['[Air]てんとう虫(瓢虫)', '[Air]てんとう虫(瓢虫)', '[Air]てんとう虫(瓢虫)', '[Air]てんとう虫(瓢虫)', '[Air]回想录', '[Air]夢語り', '[Air]夢語り', '[Air]银色', '[Air]鸟之诗', '[Air]鸟之诗', '[Air]鸟之诗', '[Air]鸟之诗', '[Angel Beats!]Brave Song', '[Angel Beats!]Brave Song', '[Angel Beats!]Brave Song', '[Angel Beats!]一番の宝物', '[Angel Beats!]一番の宝物', '[Beck]Face', '[Beck]Face', '[CLANNAD]メグメル(幻想)', '[CLANNAD]メグメル(幻想)', '[CLANNAD]メグメル(幻想)', '[CLANNAD]东风', '[CLANNAD]东风', '[CLANNAD]团子大家族', '[CLANNAD]团子大家族', '[CLANNAD]团子大家族', '[CLANNAD]欢乐岛', '[CLANNAD]欢乐岛', '[CLANNAD]欢乐岛', '[CLANNAD]汐', '[CLANNAD]汐', '[CLANNAD]白诘草', '[CLANNAD]空に光る', '[EVA]Fly me to the moon', '[EVA]Fly me to the moon', '[EVA]Fly me to the moon', '[EVA]Komm,susser tod', '[EVA]Komm,susser tod', '[EVA]残酷的天使纲领', '[EVA]残酷的天使纲领', '[EVA]残酷的天使纲领', '[EVA]残酷的天使纲领', '[Fate Stay Night]あなたがいた森', '[Fate Stay Night]あなたがいた森', '[Fate Stay Night]あなたがいた森', '[Fate Stay Night]光', '[Fate Stay Night]光', '[Fate Stay Night]光', '[Fate Stay Night]光', '[Fate Stay Night]命运の夜', '[Fate Stay Night]孤独的巡礼', 
# ...

# %%
XML_files = set(XML_files)
XML_files
# Out:
# {'[Air]てんとう虫(瓢虫)',
#  '[Air]回想录',
#  '[Air]夢語り',
#  '[Air]银色',
#  '[Air]鸟之诗',
#  '[Angel Beats!]Brave Song',
#  '[Angel Beats!]一番の宝物',
#  '[Beck]Face',
#  '[CLANNAD]メグメル(幻想)',
#  '[CLANNAD]东风',
#  '[CLANNAD]团子大家族',
#  '[CLANNAD]欢乐岛',
#  '[CLANNAD]汐',
#  '[CLANNAD]白诘草',
#  '[CLANNAD]空に光る',
#  '[EVA]Fly me to the moon',
#  '[EVA]Komm,susser tod',
#  '[EVA]残酷的天使纲领',
#  '[Fate Stay Night]あなたがいた森',
#  '[Fate Stay Night]光',
#  '[Fate Stay Night]命运の夜',
#  '[Fate Stay Night]孤独的巡礼',
#  '[Fate Zero]空は高く風は歌う',
#  '[KOKIA]ありがとう(谢谢)',
#  '[Kanon]Last Regrets',
#  '[Kanon]夢の跡',
#  '[Little Busters!]遥か彼方',
#  '[Little busters]Song for friends',
#  '[LoveLive!]夏色えがおで1,2,Jump!',
#  '[LoveLive!]愛してるばんざーい!',
#  '[NICO]Merry Christmas Mr.Lawrence',
#  '[NICO]相思花',
#  '[Narcissu]週末の過ごし方より(如何度过周末)',
#  '[Tari Tari]心の旋律',
#  '[一周的朋友]奏',
#  '[三国志]英雄的黎明',
#  '[东方妖妖梦]無何有の郷',
#  '[东方妖妖梦]色は匂へど散りぬるを',
#  '[东方永夜抄]もう歌しか聞こえない',
#  '[东方永夜抄]懐かしき東方の血',
#  '[东方绯想天则]暮色蒼然',
#  '[东方萃梦想]天衣无缝',
#  '[东方萃梦想]碎月',
# ...

# %%
full_files = os.listdir(os.getcwd() + '\\entire songs')
full_files = [file for file in full_files if '.xml' in file]

# %%
path = os.getcwd()
for file in XML_files:
    if file + '.xml' in full_files:
        print('!')
    else:
        print(file)
# Out:
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# [云之彼端,约定的地方]Hiloki‘s Melody
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# [哆啦A梦]ひまわりの约束
# !
# !
# [劲乐团]V
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
